# %% [markdown]
# #### Note: This example is compatible with versions v0.1.5 or lower, for the most recent version, see [this](https://github.com/facebookresearch/mbrl-lib/blob/main/notebooks/pets_example.ipynb) notebook.

# %%
# %%bash
#
# git clone http://github.com/ScorcaF/imitation # && git checkout 0861607f146457e3e086ee91c362c39aeac1d8c4
# cd imitation
# pip install -e .
# mv imitation/src/imitation /usr/local/lib/python3.7/dist-packages/
#
#
# # pip install mbrl
# # pip install omegaconf
# # apt-get install swig
# # pip install matplotlib==3.1.1
# # # install required system dependencies
# # apt-get install -y xvfb x11-utils
#
# # install required python dependencies (might need to install additional gym extras depending)
# # pip install gym[box2d]==0.17.* pyvirtualdisplay==0.2.* PyOpenGL==3.1.* PyOpenGL-accelerate==3.1.*
#
# # pip3 install box2d-py
# # pip3 install gym[Box_2D]
# # pip install stable_baselines3

# %%
# %%bash
# git clone https://github.com/ScorcaF/mbrl-lib.git && git checkout ScorcaF-mods
# cd mbrl-lib/
# pip install -e ".[dev]"
# mv mbrl-lib/mbrl /usr/local/lib/python3.7/dist-packages/

# %%
from IPython import display
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import torch
import omegaconf

import mbrl.env.cartpole_continuous as cartpole_env
import mbrl.env.reward_fns as reward_fns
import mbrl.env.termination_fns as termination_fns
import mbrl.models as models
import mbrl.planning as planning
import mbrl.util.common as common_util
import mbrl.util as util


# %load_ext autoreload
# %autoreload 2

mpl.rcParams.update({"font.size": 16})

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Creating the environment
#
# First we instantiate the environment and specify which reward function and termination function to use with the gym-like environment wrapper, along with some utility objects. The termination function tells the wrapper if an observation should cause an episode to end or not, and it is an input used in some algorithms, like [MBPO](https://github.com/JannerM/mbpo/blob/master/mbpo/static/halfcheetah.py). The reward function is used to compute the value of the reward given an observation, and it's used by some algorithms, like [PETS](https://github.com/kchua/handful-of-trials/blob/77fd8802cc30b7683f0227c90527b5414c0df34c/dmbrl/controllers/MPC.py#L65).

# %%
seed = 0
env = cartpole_env.CartPoleEnv()
env.seed(seed)
rng = np.random.default_rng(seed=0)
generator = torch.Generator(device=device)
generator.manual_seed(seed)
obs_shape = env.observation_space.shape
act_shape = env.action_space.shape

# This functions allows the model to evaluate the true rewards given an observation 
reward_fn = reward_fns.cartpole
# This function allows the model to know if an observation should make the episode end
term_fn = termination_fns.cartpole

# %% [markdown]
# # Hydra configuration
#
# MBRL-Lib uses [Hydra](https://github.com/facebookresearch/hydra) to manage configurations. For the purpose of this example, you can think of the configuration object as a dictionary with key/value pairs--and equivalent attributes--that specify the model and algorithmic options. Our toolbox expects the configuration object to be organized as follows:

# %%
trial_length = 200
num_trials = 10
ensemble_size = 5

# Everything with "???" indicates an option with a missing value.
# Our utility functions will fill in these details using the 
# environment information
cfg_dict = {
    # dynamics model configuration
    "dynamics_model": {
        "model": 
        {
            "_target_": "mbrl.models.GaussianMLP",
            "device": device,
            "num_layers": 3,
            "ensemble_size": ensemble_size,
            "hid_size": 200,
            "in_size": "???",
            "out_size": "???",
            "deterministic": False,
            "propagation_method": "fixed_model",
            # can also configure activation function for GaussianMLP
            "activation_fn_cfg": {
                "_target_": "torch.nn.LeakyReLU",
                "negative_slope": 0.01
            }
        }
    },
    # options for training the dynamics model
    "algorithm": {
        
        "agent" :{
          "_target_": "mbrl.third_party.pytorch_sac_pranz24.sac.SAC",
          "num_inputs": "???",
          "action_space" :
            {
              "_target_": "gym.env.Box",
              "low": "???",
              "high":"???",
              "shape": "???" },

          "args": {
            "gamma": 0.99,
            "tau": 0.005,
            "alpha": 0.2,
            "policy": "Gaussian",
            "target_update_interval": 4,
            "automatic_entropy_tuning": True,
            "target_entropy": -0.05,
            "hidden_size": 256,
            "lr": 0.0003,
            "batch_size": 256,
            "device": "cpu"
        }},

        "normalize": True,
        "normalize_double_precision": True,
        "target_is_delta": True,
        "learned_rewards": True,
        "freq_train_model": 200,
        "real_data_ratio": 0.0,
        "sac_samples_action": True,
        "initial_exploration_steps": 5000,
        "random_initial_explore": False,
        "num_eval_episodes": 1},


    # these are experiment specific options
    "overrides": {
        "num_steps": 500, #5000
        "epoch_length": 20, #200
        "num_elites": 5,
        "patience": 5,
        "model_lr": 0.001,
        "model_wd": 0.00005,
        "model_batch_size": 256,
        "validation_ratio": 0.2,
        "freq_train_model": 200,
        "effective_model_rollouts_per_step": 400,
        "rollout_schedule": [1, 15, 1, 1],
        "num_sac_updates_per_step": 20,
        "sac_updates_every_steps": 1,
        "num_epochs_to_retain_sac_buffer": 1,

        

        "sac_gamma": 0.99,
        "sac_tau": 0.005,
        "sac_alpha": 0.2,
        "sac_policy": "Gaussian",
        "sac_target_update_interval": 4,
        "sac_automatic_entropy_tuning": True,
        "sac_target_entropy": -0.05,
        "sac_hidden_size": 256,
        "sac_lr": 0.0003,
        "sac_batch_size": 256
}}
cfg = omegaconf.OmegaConf.create(cfg_dict)

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Note: </b> This example uses a probabilistic ensemble. You can also use a fully deterministic model with class GaussianMLP by setting ensemble_size=1, and deterministic=True. </div>

# %% [markdown]
# # Creating a dynamics model
#
# Given the configuration above, the following two lines of code create a wrapper for 1-D transition reward models, and a gym-like environment that wraps it, which we can use for simulating the real environment. The 1-D model wrapper takes care of creating input/output data tensors to the underlying NN model (by concatenating observations, actions and rewards appropriately), normalizing the input data to the model, and other data processing tasks (e.g., converting observation targets to deltas with respect to the input observation).

# %%
# # Create a 1-D dynamics model for this environment
# dynamics_model = common_util.create_one_dim_tr_model(cfg, obs_shape, act_shape)

# # Create a gym-like environment to encapsulate the model
# model_env = models.ModelEnv(env, dynamics_model, term_fn, reward_fn, generator=generator)

# %% [markdown]
# # Create a replay buffer
#
# We can create a replay buffer for this environment an configuration using the following method

# %%
# replay_buffer = common_util.create_replay_buffer(cfg, obs_shape, act_shape, rng=rng)

# %% [markdown]
# We can now populate the replay buffer with random trajectories of a desired length, using a single function call to `util.rollout_agent_trajectories`. Note that we pass an agent of type `planning.RandomAgent` to generate the actions; however, this method accepts any agent that is a subclass of `planning.Agent`, allowing changing exploration strategies with minimal changes to the code.

# %%
# common_util.rollout_agent_trajectories(
#     env,
#     trial_length, # initial exploration steps
#     planning.RandomAgent(env),
#     {}, # keyword arguments to pass to agent.act()
#     replay_buffer=replay_buffer,
#     trial_length=trial_length
# )

# print("# samples stored", replay_buffer.num_stored)
# Out:
# # samples stored 200

# %% [markdown]
# # SAC Agent

# %%
# agent_cfg = omegaconf.OmegaConf.create({
    
#   "_target_": "mbrl.third_party.pytorch_sac_pranz24.sac.SAC",
#   "num_inputs": "???",
#   "action_space" :
#    {
#     "_target_": "gym.env.Box",
#     "low": "???",
#     "high":"???",
#     "shape": "???" } ,

#   "args": {
#     "gamma": 0.99,
#     "tau": 0.005,
#     "alpha": 0.2,
#     "policy": "Gaussian",
#     "target_update_interval": 4,
#     "automatic_entropy_tuning": True,
#     "target_entropy": -0.05,
#     "hidden_size": 256,
#     "lr": 0.0003,
#     "batch_size": 256,
#     "device": "cpu"
# }})

# agent = planning.create_trajectory_optim_agent_for_model(
#     model_env,
#     agent_cfg,
#     num_particles=20
# )

# %% [markdown]
# # MBPO utilities

# %%
import os
from typing import Optional, Sequence, cast

import gym
import hydra.utils
import numpy as np
import omegaconf
import torch

import mbrl.constants
import mbrl.models
import mbrl.planning
import mbrl.third_party.pytorch_sac_pranz24 as pytorch_sac_pranz24 # Missing when install mbrl
import mbrl.types
import mbrl.util
import mbrl.util.common
import mbrl.util.math
from mbrl.planning.sac_wrapper import SACAgent
from mbrl.third_party.pytorch_sac import VideoRecorder

MBPO_LOG_FORMAT = mbrl.constants.EVAL_LOG_FORMAT + [
    ("epoch", "E", "int"),
    ("rollout_length", "RL", "int"),
]


# def rollout_model_and_populate_sac_buffer(
#     model_env: mbrl.models.ModelEnv,
#     replay_buffer: mbrl.util.ReplayBuffer,
#     agent: SACAgent,
#     sac_buffer: mbrl.util.ReplayBuffer,
#     sac_samples_action: bool,
#     rollout_horizon: int,
#     batch_size: int,
# ):

#     batch = replay_buffer.sample(batch_size)
#     initial_obs, *_ = cast(mbrl.types.TransitionBatch, batch).astuple()
#     model_state = model_env.reset(
#         initial_obs_batch=cast(np.ndarray, initial_obs),
#         return_as_np=True,
#     )
#     accum_dones = np.zeros(initial_obs.shape[0], dtype=bool)
#     obs = initial_obs
#     for i in range(rollout_horizon):
#         action = agent.act(obs, sample=sac_samples_action, batched=True)
#         pred_next_obs, pred_rewards, pred_dones, model_state = model_env.step(
#             action, model_state, sample=True
#         )
#         sac_buffer.add_batch(
#             obs[~accum_dones],
#             action[~accum_dones],
#             pred_next_obs[~accum_dones],
#             pred_rewards[~accum_dones, 0],
#             pred_dones[~accum_dones, 0],
#         )
#         obs = pred_next_obs
#         accum_dones |= pred_dones.squeeze()


# def evaluate(
#     env: gym.Env,
#     agent: SACAgent,
#     num_episodes: int,
#     video_recorder: VideoRecorder,
# ) -> float:
#     avg_episode_reward = 0
#     for episode in range(num_episodes):
#         obs = env.reset()
#         video_recorder.init(enabled=(episode == 0))
#         done = False
#         episode_reward = 0
#         while not done:
#             action = agent.act(obs)
#             obs, reward, done, _ = env.step(action)
#             video_recorder.record(env)
#             episode_reward += reward
#         avg_episode_reward += episode_reward
#     return avg_episode_reward / num_episodes


# def maybe_replace_sac_buffer(
#     sac_buffer: Optional[mbrl.util.ReplayBuffer],
#     obs_shape: Sequence[int],
#     act_shape: Sequence[int],
#     new_capacity: int,
#     seed: int,
# ) -> mbrl.util.ReplayBuffer:
#     if sac_buffer is None or new_capacity != sac_buffer.capacity:
#         if sac_buffer is None:
#             rng = np.random.default_rng(seed=seed)
#         else:
#             rng = sac_buffer.rng
#         new_buffer = mbrl.util.ReplayBuffer(new_capacity, obs_shape, act_shape, rng=rng)
#         if sac_buffer is None:
#             return new_buffer
#         obs, action, next_obs, reward, done = sac_buffer.get_all().astuple()
#         new_buffer.add_batch(obs, action, next_obs, reward, done)
#         return new_buffer
#     return sac_buffer

# %% [markdown]
# # Running MBPO

# %%
# ------------------- Initialization -------------------
debug_mode = cfg.get("debug_mode", False)

obs_shape = env.observation_space.shape
act_shape = env.action_space.shape

mbrl.planning.complete_agent_cfg(env, cfg.algorithm.agent)
agent = SACAgent(
    cast(pytorch_sac_pranz24.SAC, hydra.utils.instantiate(cfg.algorithm.agent))
)

work_dir = os.getcwd()
# enable_back_compatible to use pytorch_sac agent
logger = mbrl.util.Logger(work_dir, enable_back_compatible=True)
logger.register_group(
    mbrl.constants.RESULTS_LOG_NAME,
    MBPO_LOG_FORMAT,
    color="green",
    dump_frequency=1,
)
save_video = cfg.get("save_video", False)
video_recorder = VideoRecorder(work_dir if save_video else None)

rng = np.random.default_rng(seed=cfg.seed)
torch_generator = torch.Generator(device=cfg.device)
if cfg.seed is not None:
    torch_generator.manual_seed(cfg.seed)

# %%
# -------------- Create initial overrides. dataset --------------
dynamics_model = mbrl.util.common.create_one_dim_tr_model(cfg, obs_shape, act_shape)
use_double_dtype = cfg.algorithm.get("normalize_double_precision", False)
dtype = np.double if use_double_dtype else np.float32
replay_buffer = mbrl.util.common.create_replay_buffer(
    cfg,
    obs_shape,
    act_shape,
    rng=rng,
    obs_type=dtype,
    action_type=dtype,
    reward_type=dtype,
)
random_explore = cfg.algorithm.random_initial_explore
mbrl.util.common.rollout_agent_trajectories(
    env,
    cfg.algorithm.initial_exploration_steps,
    mbrl.planning.RandomAgent(env) if random_explore else agent,
    {} if random_explore else {"sample": True, "batched": False},
    replay_buffer=replay_buffer,
)

# %%
silent = False
test_env = env
# --------------------- Training Loop ---------------------
rollout_batch_size = (
    cfg.overrides.effective_model_rollouts_per_step * cfg.algorithm.freq_train_model
)
trains_per_epoch = int(
    np.ceil(cfg.overrides.epoch_length / cfg.overrides.freq_train_model)
)
updates_made = 0
env_steps = 0
model_env = mbrl.models.ModelEnv(
    env, dynamics_model, term_fn, None, generator=torch_generator
)
model_trainer = mbrl.models.ModelTrainer(
    dynamics_model,
    optim_lr=cfg.overrides.model_lr,
    weight_decay=cfg.overrides.model_wd,
    logger=None if silent else logger,
)
best_eval_reward = -np.inf
epoch = 0
sac_buffer = None
while env_steps < cfg.overrides.num_steps:
    rollout_length = int(
        mbrl.util.math.truncated_linear(
            *(cfg.overrides.rollout_schedule + [epoch + 1])
        )
    )
    sac_buffer_capacity = rollout_length * rollout_batch_size * trains_per_epoch
    sac_buffer_capacity *= cfg.overrides.num_epochs_to_retain_sac_buffer
    sac_buffer = maybe_replace_sac_buffer(
        sac_buffer, obs_shape, act_shape, sac_buffer_capacity, cfg.seed
    )
    obs, done = None, False
    for steps_epoch in range(cfg.overrides.epoch_length):
        if steps_epoch == 0 or done:
            obs, done = env.reset(), False
        # --- Doing env step and adding to model dataset ---
        next_obs, reward, done, _ = mbrl.util.common.step_env_and_add_to_buffer(
            env, obs, agent, {}, replay_buffer
        )

        # --------------- Model Training -----------------
        if (env_steps + 1) % cfg.overrides.freq_train_model == 0:
            mbrl.util.common.train_model_and_save_model_and_data(
                dynamics_model,
                model_trainer,
                cfg.overrides,
                replay_buffer,
                work_dir=work_dir,
            )

            # --------- Rollout new model and store imagined trajectories --------
            # Batch all rollouts for the next freq_train_model steps together
            rollout_model_and_populate_sac_buffer(
                model_env,
                replay_buffer,
                agent,
                sac_buffer,
                cfg.algorithm.sac_samples_action,
                rollout_length,
                rollout_batch_size,
            )

            if debug_mode:
                print(
                    f"Epoch: {epoch}. "
                    f"SAC buffer size: {len(sac_buffer)}. "
                    f"Rollout length: {rollout_length}. "
                    f"Steps: {env_steps}"
                )

        # --------------- Agent Training -----------------
        for _ in range(cfg.overrides.num_sac_updates_per_step):
            use_real_data = rng.random() < cfg.algorithm.real_data_ratio
            which_buffer = replay_buffer if use_real_data else sac_buffer
            if (env_steps + 1) % cfg.overrides.sac_updates_every_steps != 0 or len(
                which_buffer
            ) < cfg.overrides.sac_batch_size:
                break  # only update every once in a while

            agent.sac_agent.update_parameters(
                which_buffer,
                cfg.overrides.sac_batch_size,
                updates_made,
                logger,
                reverse_mask=True,
            )
            updates_made += 1
            # if not silent and updates_made % cfg.log_frequency_agent == 0:
            #     logger.dump(updates_made, save=True)

        # ------ Epoch ended (evaluate and save model) ------
        if (env_steps + 1) % cfg.overrides.epoch_length == 0:
            avg_reward = evaluate(
                test_env, agent, cfg.algorithm.num_eval_episodes, video_recorder
            )
            logger.log_data(
                mbrl.constants.RESULTS_LOG_NAME,
                {
                    "epoch": epoch,
                    "env_step": env_steps,
                    "episode_reward": avg_reward,
                    "rollout_length": rollout_length,
                },
            )
            if avg_reward > best_eval_reward:
                video_recorder.save(f"{epoch}.mp4")
                best_eval_reward = avg_reward
                agent.sac_agent.save_checkpoint(
                    ckpt_path=os.path.join(work_dir, "sac.pth")
                )
            epoch += 1

        env_steps += 1
        obs = next_obs
# Out:
# Group model_train has already been registered.
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: 237.9728 | MVSCORE: 0.0010 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -12.8112 | MVSCORE: 0.0005 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -34.4008 | MVSCORE: 0.0002 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -37.1748 | MVSCORE: 0.0001 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -38.8702 | MVSCORE: 0.0001 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -40.6386 | MVSCORE: 0.0001 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -42.3612 | MVSCORE: 0.0001 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -43.6501 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -44.8519 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -46.0301 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -46.2528 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -46.9103 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -47.3334 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -47.7271 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -47.9960 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 15 | TD: 4000 | VD: 1000 | MLOSS: -47.8480 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 16 | TD: 4000 | VD: 1000 | MLOSS: -48.0245 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 17 | TD: 4000 | VD: 1000 | MLOSS: -48.0559 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 18 | TD: 4000 | VD: 1000 | MLOSS: -48.2611 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 19 | TD: 4000 | VD: 1000 | MLOSS: -48.1944 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 20 | TD: 4000 | VD: 1000 | MLOSS: -48.2706 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 21 | TD: 4000 | VD: 1000 | MLOSS: -48.5362 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 22 | TD: 4000 | VD: 1000 | MLOSS: -48.2944 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 23 | TD: 4000 | VD: 1000 | MLOSS: -48.0282 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 24 | TD: 4000 | VD: 1000 | MLOSS: -48.4505 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 25 | TD: 4000 | VD: 1000 | MLOSS: -48.4827 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 26 | TD: 4000 | VD: 1000 | MLOSS: -48.7652 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 27 | TD: 4000 | VD: 1000 | MLOSS: -48.6061 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 28 | TD: 4000 | VD: 1000 | MLOSS: -48.4285 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 29 | TD: 4000 | VD: 1000 | MLOSS: -48.4182 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 30 | TD: 4000 | VD: 1000 | MLOSS: -48.6167 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 31 | TD: 4000 | VD: 1000 | MLOSS: -48.5733 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 32 | TD: 4000 | VD: 1000 | MLOSS: -48.6950 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 33 | TD: 4000 | VD: 1000 | MLOSS: -48.3007 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 34 | TD: 4000 | VD: 1000 | MLOSS: -48.8045 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 35 | TD: 4000 | VD: 1000 | MLOSS: -48.8066 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 36 | TD: 4000 | VD: 1000 | MLOSS: -48.3429 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 37 | TD: 4000 | VD: 1000 | MLOSS: -48.4728 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 38 | TD: 4000 | VD: 1000 | MLOSS: -48.8270 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 39 | TD: 4000 | VD: 1000 | MLOSS: -48.5329 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 40 | TD: 4000 | VD: 1000 | MLOSS: -48.3176 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 41 | TD: 4000 | VD: 1000 | MLOSS: -48.9419 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 42 | TD: 4000 | VD: 1000 | MLOSS: -48.9921 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 43 | TD: 4000 | VD: 1000 | MLOSS: -48.7874 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 44 | TD: 4000 | VD: 1000 | MLOSS: -48.2481 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 45 | TD: 4000 | VD: 1000 | MLOSS: -48.6805 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 46 | TD: 4000 | VD: 1000 | MLOSS: -48.3522 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 199 | R: 43.0000 | E: 0 | RL: 1
# Saving models to /content/mbrl-lib/sac.pth
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -43.0190 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -47.7691 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -48.5357 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -48.8839 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -48.9486 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -48.8057 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -48.9877 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -48.8442 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -49.0158 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -49.0991 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -48.0996 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -48.8736 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -48.7347 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -48.8890 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -48.8140 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 15 | TD: 4000 | VD: 1000 | MLOSS: -49.0193 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 16 | TD: 4000 | VD: 1000 | MLOSS: -48.9182 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 17 | TD: 4000 | VD: 1000 | MLOSS: -48.4637 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 18 | TD: 4000 | VD: 1000 | MLOSS: -48.7751 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 19 | TD: 4000 | VD: 1000 | MLOSS: -48.5238 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 20 | TD: 4000 | VD: 1000 | MLOSS: -48.7352 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 399 | R: 214.0000 | E: 1 | RL: 1
# Saving models to /content/mbrl-lib/sac.pth
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -42.6496 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -47.6159 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -48.5862 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -48.9475 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -49.0031 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -49.0292 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -48.5425 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -49.0696 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -49.1774 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -49.1139 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -48.9179 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -48.7646 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -48.6565 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -48.7683 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -48.9542 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 15 | TD: 4000 | VD: 1000 | MLOSS: -48.2342 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 16 | TD: 4000 | VD: 1000 | MLOSS: -48.0969 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 599 | R: 182.0000 | E: 2 | RL: 1
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -40.5952 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -47.6778 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -48.4187 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -48.7351 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -48.8587 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -49.0201 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -49.0700 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -48.5560 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -48.8040 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -48.8199 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -49.0889 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -49.0049 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -48.6833 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -48.9473 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -48.9100 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 15 | TD: 4000 | VD: 1000 | MLOSS: -47.2117 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 16 | TD: 4000 | VD: 1000 | MLOSS: -48.8308 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 17 | TD: 4000 | VD: 1000 | MLOSS: -49.0246 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 18 | TD: 4000 | VD: 1000 | MLOSS: -49.0506 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 19 | TD: 4000 | VD: 1000 | MLOSS: -48.6938 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 20 | TD: 4000 | VD: 1000 | MLOSS: -48.9088 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 21 | TD: 4000 | VD: 1000 | MLOSS: -49.1144 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 22 | TD: 4000 | VD: 1000 | MLOSS: -48.9606 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 23 | TD: 4000 | VD: 1000 | MLOSS: -49.0163 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 24 | TD: 4000 | VD: 1000 | MLOSS: -48.7728 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 25 | TD: 4000 | VD: 1000 | MLOSS: -49.1302 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 26 | TD: 4000 | VD: 1000 | MLOSS: -48.4520 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 27 | TD: 4000 | VD: 1000 | MLOSS: -48.6561 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 28 | TD: 4000 | VD: 1000 | MLOSS: -48.5284 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 29 | TD: 4000 | VD: 1000 | MLOSS: -48.9996 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 30 | TD: 4000 | VD: 1000 | MLOSS: -49.1280 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 31 | TD: 4000 | VD: 1000 | MLOSS: -49.1333 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 32 | TD: 4000 | VD: 1000 | MLOSS: -49.0085 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 33 | TD: 4000 | VD: 1000 | MLOSS: -48.8089 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 34 | TD: 4000 | VD: 1000 | MLOSS: -47.7783 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 799 | R: 239.0000 | E: 3 | RL: 1
# Saving models to /content/mbrl-lib/sac.pth
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -42.6883 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -48.1308 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -48.9674 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -49.1335 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -49.1990 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -49.1848 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -49.0689 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -49.0308 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -49.0096 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -49.2379 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -49.1338 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -48.7131 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -48.5899 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -49.0667 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -49.1551 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 15 | TD: 4000 | VD: 1000 | MLOSS: -48.9734 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 16 | TD: 4000 | VD: 1000 | MLOSS: -47.9185 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 17 | TD: 4000 | VD: 1000 | MLOSS: -49.0162 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 18 | TD: 4000 | VD: 1000 | MLOSS: -48.8485 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 19 | TD: 4000 | VD: 1000 | MLOSS: -48.7484 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 20 | TD: 4000 | VD: 1000 | MLOSS: -48.9490 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 21 | TD: 4000 | VD: 1000 | MLOSS: -49.0910 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 22 | TD: 4000 | VD: 1000 | MLOSS: -49.0726 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 23 | TD: 4000 | VD: 1000 | MLOSS: -49.0106 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 24 | TD: 4000 | VD: 1000 | MLOSS: -48.3603 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 25 | TD: 4000 | VD: 1000 | MLOSS: -48.7603 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 26 | TD: 4000 | VD: 1000 | MLOSS: -49.0072 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 27 | TD: 4000 | VD: 1000 | MLOSS: -49.1134 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 999 | R: 304.0000 | E: 4 | RL: 1
# Saving models to /content/mbrl-lib/sac.pth
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -40.4852 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -47.3990 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -48.5902 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -48.8077 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -49.0879 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -49.1461 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -49.2039 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -49.0807 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -49.1124 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -49.0481 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -49.0894 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -49.0688 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -49.0966 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -48.6566 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -48.5964 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 15 | TD: 4000 | VD: 1000 | MLOSS: -49.1128 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 16 | TD: 4000 | VD: 1000 | MLOSS: -49.1067 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 17 | TD: 4000 | VD: 1000 | MLOSS: -48.9904 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 18 | TD: 4000 | VD: 1000 | MLOSS: -48.9349 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 19 | TD: 4000 | VD: 1000 | MLOSS: -49.1154 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 20 | TD: 4000 | VD: 1000 | MLOSS: -48.7115 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 21 | TD: 4000 | VD: 1000 | MLOSS: -48.9483 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 22 | TD: 4000 | VD: 1000 | MLOSS: -48.7254 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 23 | TD: 4000 | VD: 1000 | MLOSS: -48.9090 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 24 | TD: 4000 | VD: 1000 | MLOSS: -48.8967 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 25 | TD: 4000 | VD: 1000 | MLOSS: -49.0426 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 26 | TD: 4000 | VD: 1000 | MLOSS: -49.0751 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 27 | TD: 4000 | VD: 1000 | MLOSS: -48.8422 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 28 | TD: 4000 | VD: 1000 | MLOSS: -48.9630 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 29 | TD: 4000 | VD: 1000 | MLOSS: -48.0666 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 30 | TD: 4000 | VD: 1000 | MLOSS: -48.8203 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 1199 | R: 243.0000 | E: 5 | RL: 1
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -46.9008 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -48.4422 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -48.8396 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -49.0941 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -49.1616 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -49.1881 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -49.1337 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -49.0992 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -48.9746 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -49.1367 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -48.3451 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -48.8521 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -48.9759 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -48.9353 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -49.0875 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 1399 | R: 328.0000 | E: 6 | RL: 1
# Saving models to /content/mbrl-lib/sac.pth
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -41.1506 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -47.7616 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -48.8407 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -49.1416 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -49.2071 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -49.1580 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -49.1743 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -49.2626 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -49.2828 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -49.2257 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -49.0071 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -49.1813 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -49.0597 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -48.5875 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -48.7784 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 15 | TD: 4000 | VD: 1000 | MLOSS: -49.1158 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 16 | TD: 4000 | VD: 1000 | MLOSS: -48.7450 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 17 | TD: 4000 | VD: 1000 | MLOSS: -49.0285 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 18 | TD: 4000 | VD: 1000 | MLOSS: -49.0281 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 19 | TD: 4000 | VD: 1000 | MLOSS: -49.2109 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 20 | TD: 4000 | VD: 1000 | MLOSS: -49.1193 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 21 | TD: 4000 | VD: 1000 | MLOSS: -49.1647 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 22 | TD: 4000 | VD: 1000 | MLOSS: -49.0171 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 23 | TD: 4000 | VD: 1000 | MLOSS: -48.7952 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 24 | TD: 4000 | VD: 1000 | MLOSS: -48.9757 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 25 | TD: 4000 | VD: 1000 | MLOSS: -48.7311 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 1599 | R: 267.0000 | E: 7 | RL: 1
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -45.8768 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -48.3384 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -48.8923 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -49.0788 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -49.2241 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -49.1923 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -48.9956 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -49.0631 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -49.2639 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -49.2516 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -48.2515 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -48.9242 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -49.2509 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -49.2993 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -48.6050 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 15 | TD: 4000 | VD: 1000 | MLOSS: -48.9635 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 16 | TD: 4000 | VD: 1000 | MLOSS: -48.6613 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 17 | TD: 4000 | VD: 1000 | MLOSS: -49.0044 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 18 | TD: 4000 | VD: 1000 | MLOSS: -49.2068 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 19 | TD: 4000 | VD: 1000 | MLOSS: -48.5286 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 20 | TD: 4000 | VD: 1000 | MLOSS: -49.1024 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 21 | TD: 4000 | VD: 1000 | MLOSS: -49.1506 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 22 | TD: 4000 | VD: 1000 | MLOSS: -49.2642 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 23 | TD: 4000 | VD: 1000 | MLOSS: -49.0387 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 24 | TD: 4000 | VD: 1000 | MLOSS: -48.9542 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 25 | TD: 4000 | VD: 1000 | MLOSS: -49.0461 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 26 | TD: 4000 | VD: 1000 | MLOSS: -49.0554 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 1799 | R: 379.0000 | E: 8 | RL: 1
# Saving models to /content/mbrl-lib/sac.pth
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -44.9630 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -48.3777 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -49.0858 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -49.2240 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -49.2835 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -49.2688 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -49.2665 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -49.0331 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -49.2924 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -49.0085 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -49.1915 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -49.1454 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -49.1907 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -49.0409 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -48.8026 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 15 | TD: 4000 | VD: 1000 | MLOSS: -48.9095 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 16 | TD: 4000 | VD: 1000 | MLOSS: -49.1079 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 17 | TD: 4000 | VD: 1000 | MLOSS: -48.9912 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 18 | TD: 4000 | VD: 1000 | MLOSS: -49.0414 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 19 | TD: 4000 | VD: 1000 | MLOSS: -48.7330 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 20 | TD: 4000 | VD: 1000 | MLOSS: -49.0147 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 21 | TD: 4000 | VD: 1000 | MLOSS: -49.1793 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 1999 | R: 449.0000 | E: 9 | RL: 1
# Saving models to /content/mbrl-lib/sac.pth
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -44.6023 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -48.3076 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -48.9527 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -49.1835 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -49.2917 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -49.3246 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -49.3253 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -49.3101 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -49.2053 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -49.2810 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -49.2833 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -48.3179 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -48.9547 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -49.2273 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -49.0103 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 2199 | R: 294.0000 | E: 10 | RL: 1
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -47.0684 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -48.6434 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -49.0464 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -49.2756 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -49.3264 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -49.3433 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -49.3550 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -49.2427 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -49.0969 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -49.2010 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -49.1188 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -49.0648 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -49.1864 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -48.6214 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 2399 | R: 218.0000 | E: 11 | RL: 1
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -45.0261 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -47.8883 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -48.8506 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -49.1589 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -49.2421 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -49.3134 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -49.3388 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -49.3280 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -49.2831 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -49.0234 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -48.8905 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -49.0210 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -49.2210 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -49.2636 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -49.2050 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 15 | TD: 4000 | VD: 1000 | MLOSS: -49.2911 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 16 | TD: 4000 | VD: 1000 | MLOSS: -49.2898 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 17 | TD: 4000 | VD: 1000 | MLOSS: -49.0343 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 18 | TD: 4000 | VD: 1000 | MLOSS: -49.0761 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 19 | TD: 4000 | VD: 1000 | MLOSS: -49.2007 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 20 | TD: 4000 | VD: 1000 | MLOSS: -49.1645 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 2599 | R: 218.0000 | E: 12 | RL: 1
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -44.4227 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -48.2007 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -49.0494 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -49.2609 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -49.3034 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -49.3251 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -49.3565 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -49.3561 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -48.9232 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -49.1841 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -49.2835 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -49.3254 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -49.2747 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -49.2506 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -49.2710 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 15 | TD: 4000 | VD: 1000 | MLOSS: -49.2754 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 16 | TD: 4000 | VD: 1000 | MLOSS: -49.2743 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 17 | TD: 4000 | VD: 1000 | MLOSS: -49.1855 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 18 | TD: 4000 | VD: 1000 | MLOSS: -49.1182 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 19 | TD: 4000 | VD: 1000 | MLOSS: -49.0755 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 20 | TD: 4000 | VD: 1000 | MLOSS: -49.1733 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 2799 | R: 257.0000 | E: 13 | RL: 1
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -46.7381 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -48.5235 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -49.1945 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -49.3118 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -49.3484 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -49.3492 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -49.3680 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -49.3710 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -49.2202 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -49.1148 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -49.1456 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -49.1786 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -49.1124 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -48.8402 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -48.9963 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 15 | TD: 4000 | VD: 1000 | MLOSS: -49.1163 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 16 | TD: 4000 | VD: 1000 | MLOSS: -49.2504 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 2999 | R: 305.0000 | E: 14 | RL: 1
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -46.7036 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -48.4843 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -49.1797 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -49.2080 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -49.2857 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -49.3015 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -49.3293 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -49.2368 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -49.2466 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -49.2082 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -49.2841 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -49.3197 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -49.1113 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -48.9974 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -49.2381 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 15 | TD: 4000 | VD: 1000 | MLOSS: -49.1085 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 16 | TD: 4000 | VD: 1000 | MLOSS: -48.8802 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 3199 | R: 261.0000 | E: 15 | RL: 1
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -45.8806 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -48.5366 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -49.0928 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -49.3047 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -49.3510 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -49.3565 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -49.3505 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -49.3023 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -49.0669 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -49.2127 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -49.2255 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -49.1289 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -49.2511 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -49.3575 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -49.3495 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 15 | TD: 4000 | VD: 1000 | MLOSS: -49.1124 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 16 | TD: 4000 | VD: 1000 | MLOSS: -49.0375 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 17 | TD: 4000 | VD: 1000 | MLOSS: -49.1712 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 3399 | R: 376.0000 | E: 16 | RL: 1
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -46.7700 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -48.5153 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -49.0865 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -49.2401 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -49.2918 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -49.3201 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -49.3052 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -49.2714 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -49.3446 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -49.3343 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -49.3466 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -49.2541 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -49.2536 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -48.9103 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -49.1684 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 15 | TD: 4000 | VD: 1000 | MLOSS: -49.3347 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 16 | TD: 4000 | VD: 1000 | MLOSS: -49.2677 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 3599 | R: 177.0000 | E: 17 | RL: 1
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -46.7362 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -48.3219 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -48.9554 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -49.1064 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -49.2885 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -49.3466 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -49.3661 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -49.3652 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -49.3452 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -49.3417 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -49.3262 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -49.3489 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -49.3089 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -48.9763 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -49.1332 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 15 | TD: 4000 | VD: 1000 | MLOSS: -49.2623 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 3799 | R: 205.0000 | E: 18 | RL: 1
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -47.2071 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -48.5831 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -49.0865 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -49.1881 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -49.2474 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -49.3035 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -49.3709 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -49.3801 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -49.3768 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -49.3532 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -49.2210 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -49.2224 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -49.3067 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -49.3224 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -49.3668 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 15 | TD: 4000 | VD: 1000 | MLOSS: -49.2701 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 16 | TD: 4000 | VD: 1000 | MLOSS: -49.2896 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 17 | TD: 4000 | VD: 1000 | MLOSS: -49.1870 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 18 | TD: 4000 | VD: 1000 | MLOSS: -49.1642 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 19 | TD: 4000 | VD: 1000 | MLOSS: -49.1262 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 3999 | R: 229.0000 | E: 19 | RL: 1
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -46.9170 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -48.3588 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -48.8775 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -49.0566 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -49.1949 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -49.3166 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -49.3505 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -49.3804 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -49.3862 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -49.3530 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -49.3474 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -49.2703 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -49.2914 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -49.2616 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -49.3070 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 15 | TD: 4000 | VD: 1000 | MLOSS: -49.2862 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 16 | TD: 4000 | VD: 1000 | MLOSS: -49.2312 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 17 | TD: 4000 | VD: 1000 | MLOSS: -49.1479 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 18 | TD: 4000 | VD: 1000 | MLOSS: -49.2774 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 19 | TD: 4000 | VD: 1000 | MLOSS: -49.2991 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 4199 | R: 190.0000 | E: 20 | RL: 1
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -46.3250 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -48.1276 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -48.6232 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -48.8727 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -49.0081 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -49.2051 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -49.3200 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -49.3626 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -49.3645 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -49.3642 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -49.3911 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -49.3434 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -49.3000 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -49.3731 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -49.3691 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 15 | TD: 4000 | VD: 1000 | MLOSS: -49.3386 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 16 | TD: 4000 | VD: 1000 | MLOSS: -49.1995 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 17 | TD: 4000 | VD: 1000 | MLOSS: -49.3186 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 18 | TD: 4000 | VD: 1000 | MLOSS: -49.3535 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 19 | TD: 4000 | VD: 1000 | MLOSS: -49.2846 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 4399 | R: 448.0000 | E: 21 | RL: 1
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -45.3462 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -47.8394 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -48.5259 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -48.7313 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -49.0826 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -49.2823 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -49.3170 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -49.3588 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -49.3839 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -49.3912 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -49.4085 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -49.4158 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -49.4131 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -49.4021 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -49.3751 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 15 | TD: 4000 | VD: 1000 | MLOSS: -49.2848 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 16 | TD: 4000 | VD: 1000 | MLOSS: -49.3037 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 17 | TD: 4000 | VD: 1000 | MLOSS: -49.2799 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 18 | TD: 4000 | VD: 1000 | MLOSS: -49.3397 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 19 | TD: 4000 | VD: 1000 | MLOSS: -49.3508 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 20 | TD: 4000 | VD: 1000 | MLOSS: -49.3349 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 21 | TD: 4000 | VD: 1000 | MLOSS: -49.2972 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 4599 | R: 429.0000 | E: 22 | RL: 1
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -44.4062 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -46.5985 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -48.0764 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -48.9037 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -49.2232 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -49.3170 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -49.3672 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -49.3626 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -49.3846 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -49.3537 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -49.3788 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -49.3678 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -49.3857 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -49.3278 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -49.3258 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 15 | TD: 4000 | VD: 1000 | MLOSS: -49.1931 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 16 | TD: 4000 | VD: 1000 | MLOSS: -49.2663 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 17 | TD: 4000 | VD: 1000 | MLOSS: -49.3409 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 18 | TD: 4000 | VD: 1000 | MLOSS: -49.3188 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 19 | TD: 4000 | VD: 1000 | MLOSS: -49.3402 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 20 | TD: 4000 | VD: 1000 | MLOSS: -49.4017 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 21 | TD: 4000 | VD: 1000 | MLOSS: -49.3949 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 22 | TD: 4000 | VD: 1000 | MLOSS: -49.2783 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 23 | TD: 4000 | VD: 1000 | MLOSS: -49.2519 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 24 | TD: 4000 | VD: 1000 | MLOSS: -49.3661 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 25 | TD: 4000 | VD: 1000 | MLOSS: -49.3880 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 26 | TD: 4000 | VD: 1000 | MLOSS: -49.3920 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 27 | TD: 4000 | VD: 1000 | MLOSS: -49.3997 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 28 | TD: 4000 | VD: 1000 | MLOSS: -49.3847 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 29 | TD: 4000 | VD: 1000 | MLOSS: -49.3142 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 30 | TD: 4000 | VD: 1000 | MLOSS: -49.2125 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 31 | TD: 4000 | VD: 1000 | MLOSS: -49.3705 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 32 | TD: 4000 | VD: 1000 | MLOSS: -49.4132 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 33 | TD: 4000 | VD: 1000 | MLOSS: -49.3959 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 34 | TD: 4000 | VD: 1000 | MLOSS: -49.2679 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 35 | TD: 4000 | VD: 1000 | MLOSS: -49.2951 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 36 | TD: 4000 | VD: 1000 | MLOSS: -49.3461 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 37 | TD: 4000 | VD: 1000 | MLOSS: -49.3176 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 38 | TD: 4000 | VD: 1000 | MLOSS: -49.3544 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 4799 | R: 290.0000 | E: 23 | RL: 1
# | model_train | I: 0 | E: 0 | TD: 4000 | VD: 1000 | MLOSS: -47.1568 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 1 | TD: 4000 | VD: 1000 | MLOSS: -48.5836 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 2 | TD: 4000 | VD: 1000 | MLOSS: -49.0320 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 3 | TD: 4000 | VD: 1000 | MLOSS: -49.2376 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 4 | TD: 4000 | VD: 1000 | MLOSS: -49.3133 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 5 | TD: 4000 | VD: 1000 | MLOSS: -49.2928 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 6 | TD: 4000 | VD: 1000 | MLOSS: -49.3526 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 7 | TD: 4000 | VD: 1000 | MLOSS: -49.3721 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 8 | TD: 4000 | VD: 1000 | MLOSS: -49.3190 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 9 | TD: 4000 | VD: 1000 | MLOSS: -49.3306 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 10 | TD: 4000 | VD: 1000 | MLOSS: -49.3005 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 11 | TD: 4000 | VD: 1000 | MLOSS: -49.3020 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 12 | TD: 4000 | VD: 1000 | MLOSS: -49.1080 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 13 | TD: 4000 | VD: 1000 | MLOSS: -49.0312 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 14 | TD: 4000 | VD: 1000 | MLOSS: -49.2506 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 15 | TD: 4000 | VD: 1000 | MLOSS: -49.3583 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 16 | TD: 4000 | VD: 1000 | MLOSS: -49.3615 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 17 | TD: 4000 | VD: 1000 | MLOSS: -49.2920 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 18 | TD: 4000 | VD: 1000 | MLOSS: -49.3355 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 19 | TD: 4000 | VD: 1000 | MLOSS: -49.3468 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 20 | TD: 4000 | VD: 1000 | MLOSS: -49.3660 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 21 | TD: 4000 | VD: 1000 | MLOSS: -49.3656 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 22 | TD: 4000 | VD: 1000 | MLOSS: -49.3161 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 23 | TD: 4000 | VD: 1000 | MLOSS: -49.2894 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 24 | TD: 4000 | VD: 1000 | MLOSS: -49.3397 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 25 | TD: 4000 | VD: 1000 | MLOSS: -49.3319 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 26 | TD: 4000 | VD: 1000 | MLOSS: -49.3473 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 27 | TD: 4000 | VD: 1000 | MLOSS: -49.3364 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 28 | TD: 4000 | VD: 1000 | MLOSS: -49.3685 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 29 | TD: 4000 | VD: 1000 | MLOSS: -49.3098 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 30 | TD: 4000 | VD: 1000 | MLOSS: -49.1127 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 31 | TD: 4000 | VD: 1000 | MLOSS: -49.2189 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 32 | TD: 4000 | VD: 1000 | MLOSS: -49.2808 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | model_train | I: 0 | E: 33 | TD: 4000 | VD: 1000 | MLOSS: -49.2399 | MVSCORE: 0.0000 | MBVSCORE: 0.0000
# | results | S: 4999 | R: 294.0000 | E: 24 | RL: 1

# %%
from stable_baselines3 import PPO
from stable_baselines3.ppo import MlpPolicy
import gym
import mbrl.env.cartpole_continuous as cartpole_env


env = cartpole_env.CartPoleEnv()

expert = PPO(
    policy=MlpPolicy,
    env=env,
    seed=0)
expert.learn(1_000)  # Note: set to 100000 to train a proficient expert


from imitation.data import rollout
from imitation.data.wrappers import RolloutInfoWrapper
from stable_baselines3.common.vec_env import DummyVecEnv

rollouts = rollout.rollout(
    expert,
    DummyVecEnv([lambda: RolloutInfoWrapper(env)] * 5),
    rollout.make_sample_until(min_timesteps=None, min_episodes=60),
)

# %%
from imitation.algorithms.adversarial.gail import GAIL
from imitation.rewards.reward_nets import BasicRewardNet
from imitation.util.networks import RunningNorm


from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv


#Need to manage vec envs
venv = DummyVecEnv([lambda: env] * 1)

reward_net = BasicRewardNet(
    venv.observation_space, venv.action_space, normalize_input_layer=RunningNorm
)

model_trainer = models.ModelTrainer(dynamics_model, optim_lr=1e-3, weight_decay=5e-5)

# RuntimeError: BufferingWrapper reset() before samples were accessed, n_stored = 200*times_execution
# common_util.rollout_agent_trajectories(
#     env,
#     trial_length, # initial exploration steps
#     planning.RandomAgent(env),
#     {}, # keyword arguments to pass to agent.act()
#     replay_buffer=replay_buffer,
#     trial_length=trial_length)


gail_trainer = GAIL(
    demonstrations=rollouts,
    demo_batch_size=1024,
    gen_replay_buffer_capacity=2048,
    n_disc_updates_per_round=4,
    venv=venv,
    gen_algo=agent,
    reward_net=reward_net,
    cfg=cfg,
    model_trainer=model_trainer,
    dynamics_model=dynamics_model,
    replay_buffer=replay_buffer,
    gen_train_timesteps = 2000,
    allow_variable_horizon=True, #https://imitation.readthedocs.io/en/latest/guide/variable_horizon.html,
    term_fn=term_fn,
    torch_generator=torch_generator
)
# Out:
# Running with `allow_variable_horizon` set to True. Some algorithms are biased towards shorter or longer episodes, which may significantly confound results. Additionally, even unbiased algorithms can exploit the information leak from the termination condition, producing spuriously high performance. See https://imitation.readthedocs.io/en/latest/guide/variable_horizon.html for more information.

# %%
gail_trainer.train(20000)  # Note: set to 300000 for better results
# Out:
# round:   0%|          | 0/10 [00:00<?, ?it/s]
# Saving models to /content/sac.pth
# Saving models to /content/sac.pth
# Saving models to /content/sac.pth
# Saving models to /content/sac.pth
# Saving models to /content/sac.pth
# Saving models to /content/sac.pth
# Saving models to /content/sac.pth
# Saving models to /content/sac.pth
# Saving models to /content/sac.pth
# round:   0%|          | 0/10 [02:15<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-39be68ba88c1> in <module>()
# ----> 1 gail_trainer.train(20000)  # Note: set to 300000 for better results
#
# /usr/local/lib/python3.7/dist-packages/imitation/algorithms/adversarial/common.py in train(self, total_timesteps, callback)
#     749                 with networks.training(self.reward_train):
#     750                     # switch to training mode (affects dropout, normalization)
# --> 751                     self.train_disc()
#     752             if callback:
#     753                 callback(r)
#
# /usr/local/lib/python3.7/dist-packages/imitation/algorithms/adversarial/common.py in train_disc(self, expert_samples, gen_samples)
#     368             batch = self._make_disc_train_batch(
#     369                 gen_samples=gen_samples,
# --> 370                 expert_samples=expert_samples,
#     371             )
#     372             disc_logits = self.logits_expert_is_high(
#
# /usr/local/lib/python3.7/dist-packages/imitation/algorithms/adversarial/common.py in _make_disc_train_batch(self, gen_samples, expert_samples)
#     877             obs_th = th.as_tensor(obs, device="cpu") #from typing import Optional, Sequence, cast
#     878             acts_th = th.as_tensor(acts, device="cpu")
# --> 879             log_policy_act_prob = self._get_log_policy_act_prob(obs_th, acts_th)
#     880             if log_policy_act_prob is not None:
#     881                 assert len(log_policy_act_prob) == n_samples
#
# /usr/local/lib/python3.7/dist-packages/imitation/algorithms/adversarial/common.py in _get_log_policy_act_prob(self, obs_th, acts_th)
#     772             A batch of log policy action probabilities.
#     773         """
# --> 774         if isinstance(self.policy, policies.ActorCriticPolicy):
#     775             # policies.ActorCriticPolicy has a concrete implementation of
#     776             # evaluate_actions to generate log_policy_act_prob given obs and actions.
#
# /usr/local/lib/python3.7/dist-packages/imitation/algorithms/adversarial/common.py in policy(self)
#     287     @property
#     288     def policy(self) -> policies.BasePolicy:
# --> 289         return self.gen_algo.policy
#     290
#     291     @abc.abstractmethod
#
# AttributeError: 'SACAgent' object has no attribute 'policy'
